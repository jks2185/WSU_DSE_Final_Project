# %%
import plotly.express as px


# Plot 1: Scatter plot of the 'INDEX OF CONSUMER SENTIMENT' vs. 'INDEX OF CURRENT ECONOMIC CONDITIONS'
fig1 = px.scatter(df_data, x='INDEX OF CONSUMER SENTIMENT', y='INDEX OF CURRENT ECONOMIC CONDITIONS',
                  title='Consumer sentiment vs. Current economic conditions')

# Plot 2: Histogram of 'AGE OF RESPONDENT'
fig2 = px.histogram(df_data, x='AGE OF RESPONDENT', nbins=20,
                     title='Age distribution of respondents')

# Plot 3: Bar chart of 'MARITAL STATUS OF RESPONDENT'
fig3 = px.bar(df_data, x='MARITAL STATUS OF RESPONDENT', y='TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS',
               title='Income by marital status')

# Plot 4: Box plot of 'EDUCATION OF RESPONDENT' vs. 'INDEX OF CONSUMER SENTIMENT'
fig4 = px.box(df_data, x='EDUCATION OF RESPONDENT', y='INDEX OF CONSUMER SENTIMENT',
              title='Consumer sentiment by education level')

# Plot 5: Line chart of 'INDEX OF CONSUMER EXPECTATIONS' over time
fig1 = px.line(df_data, x='SURVEY YEAR', y='INDEX OF CONSUMER EXPECTATIONS',
               title='Consumer expectations over time')

# Plot 6: Scatter plot of 'AGE OF RESPONDENT' vs. 'TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS'
fig2 = px.scatter(df_data, x='AGE OF RESPONDENT', y='TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS',
                  title='Age vs. Income')

# Plot 7: Histogram of 'INDEX OF CONSUMER EXPECTATIONS'
fig3 = px.histogram(df_data, x='INDEX OF CONSUMER EXPECTATIONS', nbins=20,
                     title='Consumer expectations distribution')

# Plot 8: Box plot of 'REGION OF RESIDENCE' vs. 'INDEX OF CURRENT ECONOMIC CONDITIONS'
fig4 = px.box(df_data, x='REGION OF RESIDENCE', y='INDEX OF CURRENT ECONOMIC CONDITIONS',
              title='Current economic conditions by region')

# Plot 9: Scatter matrix of 'INDEX OF CONSUMER EXPECTATIONS', 'INDEX OF CONSUMER SENTIMENT', and 'INDEX OF CURRENT ECONOMIC CONDITIONS'
fig5 = px.scatter_matrix(df_data, dimensions=['INDEX OF CONSUMER EXPECTATIONS', 'INDEX OF CONSUMER SENTIMENT',
                                               'INDEX OF CURRENT ECONOMIC CONDITIONS'])

# Plot 10: Bar chart of 'SEX OF RESPONDENT'
fig6 = px.bar(df_data, x='SEX OF RESPONDENT', y='TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS',
               title='Income by gender')

# Plot 11: Box plot of 'EDUCATION OF RESPONDENT' vs. 'TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS'
fig7 = px.box(df_data, x='EDUCATION OF RESPONDENT', y='TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS',
              title='Income by education level')

# Plot 12: Bar chart of 'GOVERNMENT ECONOMIC POLICY'
fig8 = px.bar(df_data, x='GOVERNMENT ECONOMIC POLICY', title='Opinion on government economic policy')

# Plot 13: Heatmap of correlation between columns
fig9 = px.imshow(df_data.corr(), title='Correlation heatmap')

# Plot 14: Violin plot of 'VEHICLE BUYING ATTITUDES' vs. 'TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS'
fig10 = px.violin(df_data, x='VEHICLE BUYING ATTITUDES', y='TOTAL HOUSEHOLD INCOME - CURRENT DOLLARS',
                  title='Income by vehicle buying attitude')
